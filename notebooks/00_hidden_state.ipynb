# %% [markdown]
# # Hidden state
#
# Run the cells top to bottom. Then run cell 2 again. Then delete cell 2 and run cell 3.

# %%
trips_per_day = 40

# %%
trips_per_day = trips_per_day * 2

# %%
print(f"trips per day: {trips_per_day}")
